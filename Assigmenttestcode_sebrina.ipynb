# %%
aggregated_df = data[['Date', 'TOTALDEMAND','PRICECATEGORY','Maximum temperature (°C)','Minimum temperature (°C)','Speed of maximum wind gust (km/h)','Rainfall (mm)']].groupby('Date').agg('max')
aggregated_df = aggregate_data[['Date', 'TOTALDEMAND','PRICECATEGORY','Maximum temperature (°C)','Minimum temperature (°C)','Speed of maximum wind gust (km/h)','Rainfall (mm)']].groupby('Date').agg('mean')
peek = aggregated_df.head(60)
peek
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-946152a98fe1> in <module>
#       1 #aggregated_df = data[['Date', 'TOTALDEMAND','PRICECATEGORY','Maximum temperature (°C)','Minimum temperature (°C)','Speed of maximum wind gust (km/h)','Rainfall (mm)']].groupby('Date').agg('max')
# ----> 2 aggregated_df = aggregate_data[['Date', 'TOTALDEMAND','PRICECATEGORY','Maximum temperature (°C)','Minimum temperature (°C)','Speed of maximum wind gust (km/h)','Rainfall (mm)']].groupby('Date').agg('mean')
#       3 peek = aggregated_df.head(60)
#       4 peek
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
# ...

# %%
aggregated_df.tail(5)
# Out:
#            TOTALDEMAND  Maximum temperature (°C)  Minimum temperature (°C)  \
# Date
# 9/04/2021     4539.437                      17.3                      13.8
# 9/05/2021     4138.748                      20.5                      11.0
# 9/06/2021     5776.989                      14.7                       7.8
# 9/07/2021     6099.853                      12.0                       2.0
# 9/08/2021     5395.073                      16.4                       7.1
#
#            Speed of maximum wind gust (km/h)  Rainfall (mm)
# Date
# 9/04/2021                               35.0            6.2
# 9/05/2021                               28.0            0.4
# 9/06/2021                               67.0            4.0
# 9/07/2021                               15.0            NaN
# 9/08/2021                               30.0            0.0

# %%
types = aggregated_df.dtypes
print(types)
# Out:
# TOTALDEMAND                          float64
# Maximum temperature (°C)             float64
# Minimum temperature (°C)             float64
# Speed of maximum wind gust (km/h)    float64
# Rainfall (mm)                        float64
# dtype: object

# %%
# Replace each null value with its mean value
newdata = aggregated_df.fillna(aggregated_df.mean())
newdata
# Out:
#            TOTALDEMAND  Maximum temperature (°C)  Minimum temperature (°C)  \
# Date
# 1/01/2021     3954.327                      29.9                      15.6
# 1/02/2021     4670.888                      20.3                      13.4
# 1/03/2021     4483.006                      21.7                      13.8
# 1/04/2021     4794.322                      29.9                      12.4
# 1/05/2021     4199.076                      24.6                      11.2
# ...                ...                       ...                       ...
# 9/04/2021     4539.437                      17.3                      13.8
# 9/05/2021     4138.748                      20.5                      11.0
# 9/06/2021     5776.989                      14.7                       7.8
# 9/07/2021     6099.853                      12.0                       2.0
# 9/08/2021     5395.073                      16.4                       7.1
#
#            Speed of maximum wind gust (km/h)  Rainfall (mm)
# ...

# %%
newdata.groupby("PRICECATEGORY")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-179b70ae7f87> in <module>
# ----> 1 newdata.groupby("PRICECATEGORY")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ...

# %%
# replaece price's category with int index 
newdata2 = newdata.replace({'LOW':0,'MEDIUM':1,'HIGH':2,'EXTREME':3},regex = True)
newdata2.head()
# Out:
#            TOTALDEMAND  PRICECATEGORY  Maximum temperature (°C)  Minimum temperature (°C)  \
# Date
# 1/01/2021      5019.64              0                      29.9                      15.6
# 1/02/2021      5228.29              1                      20.3                      13.4
# 1/03/2021      5225.37              0                      21.7                      13.8
# 1/04/2021      5807.02              1                      29.9                      12.4
# 1/05/2021      5261.09              1                      24.6                      11.2
#
#            Speed of maximum wind gust (km/h)  Rainfall (mm)
# Date
# 1/01/2021                               31.0            0.0
# 1/02/2021                               33.0            0.0
# 1/03/2021                               44.0            0.0
# 1/04/2021                               20.0            0.0
# 1/05/2021                               33.0            0.0

# %%
newdata2.isnull().any()
# Out:
# TOTALDEMAND                          False
# PRICECATEGORY                        False
# Maximum temperature (°C)             False
# Minimum temperature (°C)             False
# Speed of maximum wind gust (km/h)    False
# Rainfall (mm)                        False
# dtype: bool

# %%
types2 = newdata2.dtypes
print(types2)
# Out:
# TOTALDEMAND                          float64
# PRICECATEGORY                          int64
# Maximum temperature (°C)             float64
# Minimum temperature (°C)             float64
# Speed of maximum wind gust (km/h)    float64
# Rainfall (mm)                        float64
# dtype: object

# %%
# Plotting 2 side-by-side plots using axis

# This creates a sketch area of 1 row, 2 plots
# ax1 and ax2 refer to the 2 "axis"
fig, (ax1, ax2) = plt.subplots(1, 2) 

# Title for both plots
fig.suptitle('Distribution of TOTALDEMAND') 

# Draw the first plot: Box plot
ax1.boxplot(newdata3['TOTALDEMAND']) 

# Draw the second plot: Histogram
ax2.hist(newdata3['TOTALDEMAND'])
