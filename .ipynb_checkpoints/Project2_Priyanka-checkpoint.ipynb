# %%
import pandas as pd
import seaborn as sns
import csv 
import numpy as np

# %%
df1 = pd.read_csv('price_demand_data.csv')
df2 = pd.read_csv('weather_data.csv')

# %%
df1['Date'] = df1['SETTLEMENTDATE'].apply(lambda x: x.split()[0])
df1.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date
# 0   VIC1  1/01/2021 0:30      4179.21           LOW  1/01/2021
# 1   VIC1  1/01/2021 1:00      4047.76           LOW  1/01/2021
# 2   VIC1  1/01/2021 1:30      3934.70           LOW  1/01/2021
# 3   VIC1  1/01/2021 2:00      3766.45           LOW  1/01/2021
# 4   VIC1  1/01/2021 2:30      3590.37           LOW  1/01/2021

# %%
newdf1 = df1.groupby('Date').max('TOTALDEMAND')
newdf1
# Out:
#            TOTALDEMAND
# Date
# 1/01/2021      5019.64
# 1/02/2021      5228.29
# 1/03/2021      5225.37
# 1/04/2021      5807.02
# 1/05/2021      5261.09
# ...                ...
# 9/04/2021      5688.63
# 9/05/2021      5222.89
# 9/06/2021      7224.91
# 9/07/2021      7536.11
# 9/08/2021      6675.69
#
# [244 rows x 1 columns]

# %%
data = df1.merge(df2, left_on='Date', right_on='Date')
data
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        Date  \
# 0       VIC1    1/01/2021 0:30      4179.21           LOW   1/01/2021
# 1       VIC1    1/01/2021 1:00      4047.76           LOW   1/01/2021
# 2       VIC1    1/01/2021 1:30      3934.70           LOW   1/01/2021
# 3       VIC1    1/01/2021 2:00      3766.45           LOW   1/01/2021
# 4       VIC1    1/01/2021 2:30      3590.37           LOW   1/01/2021
# ...      ...               ...          ...           ...         ...
# 11658   VIC1  31/08/2021 21:30      5075.93        MEDIUM  31/08/2021
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM  31/08/2021
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM  31/08/2021
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM  31/08/2021
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM  31/08/2021
#
#        Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                          15.6                      29.9            0.0
# 1                          15.6                      29.9            0.0
# 2                          15.6                      29.9            0.0
# 3                          15.6                      29.9            0.0
# 4                          15.6                      29.9            0.0
# ...                         ...                       ...            ...
# 11658                      11.0                      20.1            0.0
# 11659                      11.0                      20.1            0.0
# 11660                      11.0                      20.1            0.0
# 11661                      11.0                      20.1            0.0
# 11662                      11.0                      20.1            0.0
#
#        Evaporation (mm)  Sunshine (hours)  ... 9am cloud amount (oktas)  \
# 0                   2.8               9.3  ...                        6
# 1                   2.8               9.3  ...                        6
# 2                   2.8               9.3  ...                        6
# 3                   2.8               9.3  ...                        6
# 4                   2.8               9.3  ...                        6
# ...                 ...               ...  ...                      ...
# 11658               5.8               3.6  ...                        7
# 11659               5.8               3.6  ...                        7
# 11660               5.8               3.6  ...                        7
# 11661               5.8               3.6  ...                        7
# 11662               5.8               3.6  ...                        7
#
#        9am wind direction 9am wind speed (km/h)  9am MSL pressure (hPa)  \
# 0                       N                     2                  1018.8
# 1                       N                     2                  1018.8
# 2                       N                     2                  1018.8
# 3                       N                     2                  1018.8
# 4                       N                     2                  1018.8
# ...                   ...                   ...                     ...
# 11658                   N                    17                     NaN
# 11659                   N                    17                     NaN
# 11660                   N                    17                     NaN
# 11661                   N                    17                     NaN
# 11662                   N                    17                     NaN
#
#        3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                      28.1                         43
# 1                      28.1                         43
# 2                      28.1                         43
# 3                      28.1                         43
# 4                      28.1                         43
# ...                     ...                        ...
# 11658                  19.4                         43
# 11659                  19.4                         43
# 11660                  19.4                         43
# 11661                  19.4                         43
# 11662                  19.4                         43
#
#       3pm cloud amount (oktas) 3pm wind direction  3pm wind speed (km/h)  \
# 0                          5.0                  E                     13
# 1                          5.0                  E                     13
# 2                          5.0                  E                     13
# 3                          5.0                  E                     13
# 4                          5.0                  E                     13
# ...                        ...                ...                    ...
# 11658                      6.0                  N                     30
# 11659                      6.0                  N                     30
# 11660                      6.0                  N                     30
# 11661                      6.0                  N                     30
# 11662                      6.0                  N                     30
#
#        3pm MSL pressure (hPa)
# 0                      1015.3
# 1                      1015.3
# 2                      1015.3
# 3                      1015.3
# 4                      1015.3
# ...                       ...
# 11658                  1012.2
# 11659                  1012.2
# 11660                  1012.2
# 11661                  1012.2
# 11662                  1012.2
#
# [11663 rows x 25 columns]

# %%
data.columns
# Out:
# Index(['REGION', 'SETTLEMENTDATE', 'TOTALDEMAND', 'PRICECATEGORY', 'Date',
#        'Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)',
#        'Evaporation (mm)', 'Sunshine (hours)',
#        'Direction of maximum wind gust ', 'Speed of maximum wind gust (km/h)',
#        'Time of maximum wind gust', '9am Temperature (°C)',
#        '9am relative humidity (%)', '9am cloud amount (oktas)',
#        '9am wind direction', '9am wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)', '3pm wind direction',
#        '3pm wind speed (km/h)', '3pm MSL pressure (hPa)'],
#       dtype='object')

# %%
data.shape
# Out:
# (11663, 25)

# %%
data.describe()
# Out:
#         TOTALDEMAND  Minimum temperature (°C)  Maximum temperature (°C)  \
# count  11663.000000              11615.000000              11615.000000
# mean    4925.808274                 11.050435                 19.444968
# std      876.444423                  3.862339                  5.342591
# min     2708.530000                  1.700000                 10.600000
# 25%     4255.490000                  8.100000                 15.500000
# 50%     4803.730000                 10.900000                 18.300000
# 75%     5477.375000                 13.800000                 21.800000
# max     8196.830000                 22.200000                 39.200000
#
#        Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# count   11567.000000      11663.000000      11663.000000
# mean        1.576900          3.902564          5.349044
# std         4.489775          2.696787          3.597600
# min         0.000000          0.000000          0.000000
# 25%         0.000000          1.800000          2.100000
# 50%         0.000000          3.200000          4.900000
# 75%         0.600000          5.600000          8.400000
# max        43.200000         13.800000         13.100000
#
#        Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# count                       11519.000000          11615.000000
# mean                           34.412796             13.720189
# std                            10.887466              4.297780
# min                            15.000000              3.000000
# 25%                            28.000000             10.900000
# 50%                            33.000000             13.400000
# 75%                            41.000000             16.400000
# max                            67.000000             30.900000
#
#        9am relative humidity (%)  9am cloud amount (oktas)  \
# count               11615.000000              11663.000000
# mean                   74.454326                  5.164537
# std                    14.149469                  2.557707
# min                    25.000000                  0.000000
# 25%                    65.000000                  3.000000
# 50%                    75.000000                  7.000000
# 75%                    84.000000                  7.000000
# max                   100.000000                  8.000000
#
#        9am MSL pressure (hPa)  3pm Temperature (°C)  \
# count            11567.000000          11663.000000
# mean              1017.740572             18.039467
# std                  7.668102              4.952872
# min                989.700000              8.600000
# 25%               1012.800000             14.400000
# 50%               1018.100000             17.100000
# 75%               1023.700000             20.200000
# max               1034.200000             35.200000
#
#        3pm relative humidity (%)  3pm cloud amount (oktas)  \
# count               11663.000000              11615.000000
# mean                   56.931236                  5.301679
# std                    13.989108                  2.387307
# min                    21.000000                  0.000000
# 25%                    48.000000                  3.000000
# 50%                    56.000000                  7.000000
# 75%                    66.000000                  7.000000
# max                    98.000000                  8.000000
#
#        3pm MSL pressure (hPa)
# count            11615.000000
# mean              1015.824839
# std                  7.421117
# min                989.000000
# 25%               1011.000000
# 50%               1015.800000
# 75%               1021.600000
# max               1032.400000

# %%
#visulaization

# %%
data.isnull().sum()
# Out:
# REGION                                 0
# SETTLEMENTDATE                         0
# TOTALDEMAND                            0
# PRICECATEGORY                          0
# Date                                   0
# Minimum temperature (°C)              48
# Maximum temperature (°C)              48
# Rainfall (mm)                         96
# Evaporation (mm)                       0
# Sunshine (hours)                       0
# Direction of maximum wind gust       144
# Speed of maximum wind gust (km/h)    144
# Time of maximum wind gust            144
# 9am Temperature (°C)                  48
# 9am relative humidity (%)             48
# 9am cloud amount (oktas)               0
# 9am wind direction                    48
# 9am wind speed (km/h)                 48
# 9am MSL pressure (hPa)                96
# 3pm Temperature (°C)                   0
# 3pm relative humidity (%)              0
# 3pm cloud amount (oktas)              48
# 3pm wind direction                     0
# 3pm wind speed (km/h)                  0
# 3pm MSL pressure (hPa)                48
# dtype: int64

# %%
data.mean()
# Out:
# TOTALDEMAND                          4925.808274
# Minimum temperature (°C)               11.050435
# Maximum temperature (°C)               19.444968
# Rainfall (mm)                           1.576900
# Evaporation (mm)                        3.902564
# Sunshine (hours)                        5.349044
# Speed of maximum wind gust (km/h)      34.412796
# 9am Temperature (°C)                   13.720189
# 9am relative humidity (%)              74.454326
# 9am cloud amount (oktas)                5.164537
# 9am MSL pressure (hPa)               1017.740572
# 3pm Temperature (°C)                   18.039467
# 3pm relative humidity (%)              56.931236
# 3pm cloud amount (oktas)                5.301679
# 3pm MSL pressure (hPa)               1015.824839
# dtype: float64

# %%
#Fill the null values with mean values
new_data = data.fillna(data.mean())
new_data
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        Date  \
# 0       VIC1    1/01/2021 0:30      4179.21           LOW   1/01/2021
# 1       VIC1    1/01/2021 1:00      4047.76           LOW   1/01/2021
# 2       VIC1    1/01/2021 1:30      3934.70           LOW   1/01/2021
# 3       VIC1    1/01/2021 2:00      3766.45           LOW   1/01/2021
# 4       VIC1    1/01/2021 2:30      3590.37           LOW   1/01/2021
# ...      ...               ...          ...           ...         ...
# 11658   VIC1  31/08/2021 21:30      5075.93        MEDIUM  31/08/2021
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM  31/08/2021
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM  31/08/2021
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM  31/08/2021
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM  31/08/2021
#
#        Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                          15.6                      29.9            0.0
# 1                          15.6                      29.9            0.0
# 2                          15.6                      29.9            0.0
# 3                          15.6                      29.9            0.0
# 4                          15.6                      29.9            0.0
# ...                         ...                       ...            ...
# 11658                      11.0                      20.1            0.0
# 11659                      11.0                      20.1            0.0
# 11660                      11.0                      20.1            0.0
# 11661                      11.0                      20.1            0.0
# 11662                      11.0                      20.1            0.0
#
#        Evaporation (mm)  Sunshine (hours)  ... 9am cloud amount (oktas)  \
# 0                   2.8               9.3  ...                        6
# 1                   2.8               9.3  ...                        6
# 2                   2.8               9.3  ...                        6
# 3                   2.8               9.3  ...                        6
# 4                   2.8               9.3  ...                        6
# ...                 ...               ...  ...                      ...
# 11658               5.8               3.6  ...                        7
# 11659               5.8               3.6  ...                        7
# 11660               5.8               3.6  ...                        7
# 11661               5.8               3.6  ...                        7
# 11662               5.8               3.6  ...                        7
#
#        9am wind direction 9am wind speed (km/h)  9am MSL pressure (hPa)  \
# 0                       N                     2             1018.800000
# 1                       N                     2             1018.800000
# 2                       N                     2             1018.800000
# 3                       N                     2             1018.800000
# 4                       N                     2             1018.800000
# ...                   ...                   ...                     ...
# 11658                   N                    17             1017.740572
# 11659                   N                    17             1017.740572
# 11660                   N                    17             1017.740572
# 11661                   N                    17             1017.740572
# 11662                   N                    17             1017.740572
#
#        3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                      28.1                         43
# 1                      28.1                         43
# 2                      28.1                         43
# 3                      28.1                         43
# 4                      28.1                         43
# ...                     ...                        ...
# 11658                  19.4                         43
# 11659                  19.4                         43
# 11660                  19.4                         43
# 11661                  19.4                         43
# 11662                  19.4                         43
#
#       3pm cloud amount (oktas) 3pm wind direction  3pm wind speed (km/h)  \
# 0                          5.0                  E                     13
# 1                          5.0                  E                     13
# 2                          5.0                  E                     13
# 3                          5.0                  E                     13
# 4                          5.0                  E                     13
# ...                        ...                ...                    ...
# 11658                      6.0                  N                     30
# 11659                      6.0                  N                     30
# 11660                      6.0                  N                     30
# 11661                      6.0                  N                     30
# 11662                      6.0                  N                     30
#
#        3pm MSL pressure (hPa)
# 0                      1015.3
# 1                      1015.3
# 2                      1015.3
# 3                      1015.3
# 4                      1015.3
# ...                       ...
# 11658                  1012.2
# 11659                  1012.2
# 11660                  1012.2
# 11661                  1012.2
# 11662                  1012.2
#
# [11663 rows x 25 columns]

# %%
new_data.isnull().sum()
# Out:
# REGION                                 0
# SETTLEMENTDATE                         0
# TOTALDEMAND                            0
# PRICECATEGORY                          0
# Date                                   0
# Minimum temperature (°C)               0
# Maximum temperature (°C)               0
# Rainfall (mm)                          0
# Evaporation (mm)                       0
# Sunshine (hours)                       0
# Direction of maximum wind gust       144
# Speed of maximum wind gust (km/h)      0
# Time of maximum wind gust            144
# 9am Temperature (°C)                   0
# 9am relative humidity (%)              0
# 9am cloud amount (oktas)               0
# 9am wind direction                    48
# 9am wind speed (km/h)                 48
# 9am MSL pressure (hPa)                 0
# 3pm Temperature (°C)                   0
# 3pm relative humidity (%)              0
# 3pm cloud amount (oktas)               0
# 3pm wind direction                     0
# 3pm wind speed (km/h)                  0
# 3pm MSL pressure (hPa)                 0
# dtype: int64

# %%
#final_data = new_data.groupby('Date').max('SETTLEMENTDATE')
#final_data = new_data.groupby('Date').max('Maximum temperature (°C)')
#final_data = new_data.groupby('Date').max('TOTALDEMAND')

# %%
final_data = new_data.groupby('Date').max()
final_data
# Out:
#           REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY  \
# Date
# 1/01/2021   VIC1  1/01/2021 9:30      5019.64           LOW
# 1/02/2021   VIC1  1/02/2021 9:30      5228.29        MEDIUM
# 1/03/2021   VIC1  1/03/2021 9:30      5225.37           LOW
# 1/04/2021   VIC1  1/04/2021 9:30      5807.02        MEDIUM
# 1/05/2021   VIC1  1/05/2021 9:30      5261.09        MEDIUM
# ...          ...             ...          ...           ...
# 9/04/2021   VIC1  9/04/2021 9:30      5688.63        MEDIUM
# 9/05/2021   VIC1  9/05/2021 9:30      5222.89        MEDIUM
# 9/06/2021   VIC1  9/06/2021 9:30      7224.91        MEDIUM
# 9/07/2021   VIC1  9/07/2021 9:30      7536.11          HIGH
# 9/08/2021   VIC1  9/08/2021 9:30      6675.69        MEDIUM
#
#            Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 1/01/2021                      15.6                      29.9         0.0000
# 1/02/2021                      13.4                      20.3         0.0000
# 1/03/2021                      13.8                      21.7         0.0000
# 1/04/2021                      12.4                      29.9         0.0000
# 1/05/2021                      11.2                      24.6         0.0000
# ...                             ...                       ...            ...
# 9/04/2021                      13.8                      17.3         6.2000
# 9/05/2021                      11.0                      20.5         0.4000
# 9/06/2021                       7.8                      14.7         4.0000
# 9/07/2021                       2.0                      12.0         1.5769
# 9/08/2021                       7.1                      16.4         0.0000
#
#            Evaporation (mm)  Sunshine (hours) Direction of maximum wind gust   \
# Date
# 1/01/2021               2.8               9.3                             NNE
# 1/02/2021               7.4               1.6                               S
# 1/03/2021               6.4               6.3                               S
# 1/04/2021               4.4              10.8                             NNW
# 1/05/2021               5.4               7.1                               N
# ...                     ...               ...                             ...
# 9/04/2021               6.4               7.9                               S
# 9/05/2021               0.0               7.1                              NW
# 9/06/2021               1.6               0.5                               S
# 9/07/2021               1.0               9.0                             NNE
# 9/08/2021               2.8               2.7                               N
#
#            ...  9am cloud amount (oktas) 9am wind direction  \
# Date       ...
# 1/01/2021  ...                         6                  N
# 1/02/2021  ...                         7                  N
# 1/03/2021  ...                         6                WSW
# 1/04/2021  ...                         1                 NE
# 1/05/2021  ...                         3                NNE
# ...        ...                       ...                ...
# 9/04/2021  ...                         5                  W
# 9/05/2021  ...                         6
# 9/06/2021  ...                         7                SSW
# 9/07/2021  ...                         4                 NE
# 9/08/2021  ...                         7                NNE
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 1/01/2021                      2                  1018.8
# 1/02/2021                      7                  1012.8
# 1/03/2021                      6                  1012.3
# 1/04/2021                      9                  1024.3
# 1/05/2021                      9                  1027.3
# ...                          ...                     ...
# 9/04/2021                     13                  1010.0
# 9/05/2021                   Calm                  1018.4
# 9/06/2021                      4                  1010.7
# 9/07/2021                      4                  1017.9
# 9/08/2021                      9                  1028.1
#
#            3pm Temperature (°C) 3pm relative humidity (%)  \
# Date
# 1/01/2021                  28.1                        43
# 1/02/2021                  19.4                        69
# 1/03/2021                  19.7                        67
# 1/04/2021                  28.7                        30
# 1/05/2021                  24.2                        35
# ...                         ...                       ...
# 9/04/2021                  15.7                        62
# 9/05/2021                  19.5                        45
# 9/06/2021                  12.3                        86
# 9/07/2021                  11.0                        67
# 9/08/2021                  15.1                        60
#
#           3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# Date
# 1/01/2021                      5.0                   E                     13
# 1/02/2021                      7.0                   S                     13
# 1/03/2021                      6.0                   S                     15
# 1/04/2021                      3.0                  SE                      7
# 1/05/2021                      7.0                   N                     17
# ...                            ...                 ...                    ...
# 9/04/2021                      6.0                   S                     17
# 9/05/2021                      3.0                 WNW                      6
# 9/06/2021                      8.0                   S                     20
# 9/07/2021                      2.0                 SSW                      7
# 9/08/2021                      6.0                 NNW                     19
#
#            3pm MSL pressure (hPa)
# Date
# 1/01/2021                  1015.3
# 1/02/2021                  1011.9
# 1/03/2021                  1012.2
# 1/04/2021                  1021.6
# 1/05/2021                  1024.4
# ...                           ...
# 9/04/2021                  1009.6
# 9/05/2021                  1014.9
# 9/06/2021                  1008.8
# 9/07/2021                  1015.7
# 9/08/2021                  1023.3
#
# [243 rows x 24 columns]

# %%
final_data["MEANTEMPERATURE"] = (final_data['Minimum temperature (°C)'] + final_data['Maximum temperature (°C)'])/2
final_data['Relative Humidity'] = final_data['3pm relative humidity (%)']/100

# %%
final_data.corr(method='pearson')
# Out:
#                                    TOTALDEMAND  Minimum temperature (°C)  \
# TOTALDEMAND                           1.000000                 -0.488245
# Minimum temperature (°C)             -0.488245                  1.000000
# Maximum temperature (°C)             -0.290005                  0.707525
# Rainfall (mm)                        -0.072715                  0.043400
# Evaporation (mm)                     -0.264008                  0.655132
# Sunshine (hours)                     -0.139581                  0.081808
# Speed of maximum wind gust (km/h)     0.081024                  0.055599
# 9am Temperature (°C)                 -0.390844                  0.915726
# 9am relative humidity (%)             0.103267                 -0.333647
# 9am cloud amount (oktas)             -0.167373                  0.206492
# 9am MSL pressure (hPa)                0.051993                 -0.326020
# 3pm Temperature (°C)                 -0.325252                  0.661643
# 3pm relative humidity (%)             0.064301                 -0.055004
# 3pm cloud amount (oktas)              0.070940                  0.062040
# 3pm MSL pressure (hPa)               -0.005067                 -0.278156
# MEANTEMPERATURE                      -0.402986                  0.896549
# Relative Humidity                     0.064301                 -0.055004
#
#                                    Maximum temperature (°C)  Rainfall (mm)  \
# TOTALDEMAND                                       -0.290005      -0.072715
# Minimum temperature (°C)                           0.707525       0.043400
# Maximum temperature (°C)                           1.000000      -0.124821
# Rainfall (mm)                                     -0.124821       1.000000
# Evaporation (mm)                                   0.620700      -0.044562
# Sunshine (hours)                                   0.469055      -0.146529
# Speed of maximum wind gust (km/h)                 -0.056155       0.042003
# 9am Temperature (°C)                               0.820029      -0.020988
# 9am relative humidity (%)                         -0.309292       0.194397
# 9am cloud amount (oktas)                          -0.170133       0.069613
# 9am MSL pressure (hPa)                            -0.101655      -0.138618
# 3pm Temperature (°C)                               0.965135      -0.126890
# 3pm relative humidity (%)                         -0.456640       0.194560
# 3pm cloud amount (oktas)                          -0.238615       0.111460
# 3pm MSL pressure (hPa)                            -0.178446      -0.056881
# MEANTEMPERATURE                                    0.947355      -0.058573
# Relative Humidity                                 -0.456640       0.194560
#
#                                    Evaporation (mm)  Sunshine (hours)  \
# TOTALDEMAND                               -0.264008         -0.139581
# Minimum temperature (°C)                   0.655132          0.081808
# Maximum temperature (°C)                   0.620700          0.469055
# Rainfall (mm)                             -0.044562         -0.146529
# Evaporation (mm)                           1.000000          0.273256
# Sunshine (hours)                           0.273256          1.000000
# Speed of maximum wind gust (km/h)          0.158109         -0.058401
# 9am Temperature (°C)                       0.705836          0.197050
# 9am relative humidity (%)                 -0.528364         -0.237637
# 9am cloud amount (oktas)                   0.014322         -0.596661
# 9am MSL pressure (hPa)                    -0.272173          0.206708
# 3pm Temperature (°C)                       0.560214          0.487546
# 3pm relative humidity (%)                 -0.208511         -0.550315
# 3pm cloud amount (oktas)                  -0.095795         -0.722233
# 3pm MSL pressure (hPa)                    -0.254226          0.132140
# MEANTEMPERATURE                            0.685875          0.331064
# Relative Humidity                         -0.208511         -0.550315
#
#                                    Speed of maximum wind gust (km/h)  \
# TOTALDEMAND                                                 0.081024
# Minimum temperature (°C)                                    0.055599
# Maximum temperature (°C)                                   -0.056155
# Rainfall (mm)                                               0.042003
# Evaporation (mm)                                            0.158109
# Sunshine (hours)                                           -0.058401
# Speed of maximum wind gust (km/h)                           1.000000
# 9am Temperature (°C)                                        0.108981
# 9am relative humidity (%)                                  -0.392071
# 9am cloud amount (oktas)                                    0.025506
# 9am MSL pressure (hPa)                                     -0.414805
# 3pm Temperature (°C)                                       -0.097804
# 3pm relative humidity (%)                                  -0.083759
# 3pm cloud amount (oktas)                                    0.135831
# 3pm MSL pressure (hPa)                                     -0.426558
# MEANTEMPERATURE                                            -0.010007
# Relative Humidity                                          -0.083759
#
#                                    9am Temperature (°C)  \
# TOTALDEMAND                                   -0.390844
# Minimum temperature (°C)                       0.915726
# Maximum temperature (°C)                       0.820029
# Rainfall (mm)                                 -0.020988
# Evaporation (mm)                               0.705836
# Sunshine (hours)                               0.197050
# Speed of maximum wind gust (km/h)              0.108981
# 9am Temperature (°C)                           1.000000
# 9am relative humidity (%)                     -0.467492
# 9am cloud amount (oktas)                       0.071326
# 9am MSL pressure (hPa)                        -0.285478
# 3pm Temperature (°C)                           0.761580
# 3pm relative humidity (%)                     -0.157132
# 3pm cloud amount (oktas)                      -0.003271
# 3pm MSL pressure (hPa)                        -0.277634
# MEANTEMPERATURE                                0.928882
# Relative Humidity                             -0.157132
#
#                                    9am relative humidity (%)  \
# TOTALDEMAND                                         0.103267
# Minimum temperature (°C)                           -0.333647
# Maximum temperature (°C)                           -0.309292
# Rainfall (mm)                                       0.194397
# Evaporation (mm)                                   -0.528364
# Sunshine (hours)                                   -0.237637
# Speed of maximum wind gust (km/h)                  -0.392071
# 9am Temperature (°C)                               -0.467492
# 9am relative humidity (%)                           1.000000
# 9am cloud amount (oktas)                            0.063188
# 9am MSL pressure (hPa)                              0.142822
# 3pm Temperature (°C)                               -0.261353
# 3pm relative humidity (%)                           0.402235
# 3pm cloud amount (oktas)                            0.031220
# 3pm MSL pressure (hPa)                              0.138699
# MEANTEMPERATURE                                    -0.345030
# Relative Humidity                                   0.402235
#
#                                    9am cloud amount (oktas)  \
# TOTALDEMAND                                       -0.167373
# Minimum temperature (°C)                           0.206492
# Maximum temperature (°C)                          -0.170133
# Rainfall (mm)                                      0.069613
# Evaporation (mm)                                   0.014322
# Sunshine (hours)                                  -0.596661
# Speed of maximum wind gust (km/h)                  0.025506
# 9am Temperature (°C)                               0.071326
# 9am relative humidity (%)                          0.063188
# 9am cloud amount (oktas)                           1.000000
# 9am MSL pressure (hPa)                            -0.198457
# 3pm Temperature (°C)                              -0.181595
# 3pm relative humidity (%)                          0.424203
# 3pm cloud amount (oktas)                           0.392260
# 3pm MSL pressure (hPa)                            -0.121681
# MEANTEMPERATURE                                   -0.013081
# Relative Humidity                                  0.424203
#
#                                    9am MSL pressure (hPa)  \
# TOTALDEMAND                                      0.051993
# Minimum temperature (°C)                        -0.326020
# Maximum temperature (°C)                        -0.101655
# Rainfall (mm)                                   -0.138618
# Evaporation (mm)                                -0.272173
# Sunshine (hours)                                 0.206708
# Speed of maximum wind gust (km/h)               -0.414805
# 9am Temperature (°C)                            -0.285478
# 9am relative humidity (%)                        0.142822
# 9am cloud amount (oktas)                        -0.198457
# 9am MSL pressure (hPa)                           1.000000
# 3pm Temperature (°C)                            -0.039200
# 3pm relative humidity (%)                       -0.143373
# 3pm cloud amount (oktas)                        -0.287894
# 3pm MSL pressure (hPa)                           0.953836
# MEANTEMPERATURE                                 -0.211430
# Relative Humidity                               -0.143373
#
#                                    3pm Temperature (°C)  \
# TOTALDEMAND                                   -0.325252
# Minimum temperature (°C)                       0.661643
# Maximum temperature (°C)                       0.965135
# Rainfall (mm)                                 -0.126890
# Evaporation (mm)                               0.560214
# Sunshine (hours)                               0.487546
# Speed of maximum wind gust (km/h)             -0.097804
# 9am Temperature (°C)                           0.761580
# 9am relative humidity (%)                     -0.261353
# 9am cloud amount (oktas)                      -0.181595
# 9am MSL pressure (hPa)                        -0.039200
# 3pm Temperature (°C)                           1.000000
# 3pm relative humidity (%)                     -0.543138
# 3pm cloud amount (oktas)                      -0.274482
# 3pm MSL pressure (hPa)                        -0.130987
# MEANTEMPERATURE                                0.904714
# Relative Humidity                             -0.543138
#
#                                    3pm relative humidity (%)  \
# TOTALDEMAND                                         0.064301
# Minimum temperature (°C)                           -0.055004
# Maximum temperature (°C)                           -0.456640
# Rainfall (mm)                                       0.194560
# Evaporation (mm)                                   -0.208511
# Sunshine (hours)                                   -0.550315
# Speed of maximum wind gust (km/h)                  -0.083759
# 9am Temperature (°C)                               -0.157132
# 9am relative humidity (%)                           0.402235
# 9am cloud amount (oktas)                            0.424203
# 9am MSL pressure (hPa)                             -0.143373
# 3pm Temperature (°C)                               -0.543138
# 3pm relative humidity (%)                           1.000000
# 3pm cloud amount (oktas)                            0.342130
# 3pm MSL pressure (hPa)                             -0.031047
# MEANTEMPERATURE                                    -0.311138
# Relative Humidity                                   1.000000
#
#                                    3pm cloud amount (oktas)  \
# TOTALDEMAND                                        0.070940
# Minimum temperature (°C)                           0.062040
# Maximum temperature (°C)                          -0.238615
# Rainfall (mm)                                      0.111460
# Evaporation (mm)                                  -0.095795
# Sunshine (hours)                                  -0.722233
# Speed of maximum wind gust (km/h)                  0.135831
# 9am Temperature (°C)                              -0.003271
# 9am relative humidity (%)                          0.031220
# 9am cloud amount (oktas)                           0.392260
# 9am MSL pressure (hPa)                            -0.287894
# 3pm Temperature (°C)                              -0.274482
# 3pm relative humidity (%)                          0.342130
# 3pm cloud amount (oktas)                           1.000000
# 3pm MSL pressure (hPa)                            -0.225539
# MEANTEMPERATURE                                   -0.121452
# Relative Humidity                                  0.342130
#
#                                    3pm MSL pressure (hPa)  MEANTEMPERATURE  \
# TOTALDEMAND                                     -0.005067        -0.402986
# Minimum temperature (°C)                        -0.278156         0.896549
# Maximum temperature (°C)                        -0.178446         0.947355
# Rainfall (mm)                                   -0.056881        -0.058573
# Evaporation (mm)                                -0.254226         0.685875
# Sunshine (hours)                                 0.132140         0.331064
# Speed of maximum wind gust (km/h)               -0.426558        -0.010007
# 9am Temperature (°C)                            -0.277634         0.928882
# 9am relative humidity (%)                        0.138699        -0.345030
# 9am cloud amount (oktas)                        -0.121681        -0.013081
# 9am MSL pressure (hPa)                           0.953836        -0.211430
# 3pm Temperature (°C)                            -0.130987         0.904714
# 3pm relative humidity (%)                       -0.031047        -0.311138
# 3pm cloud amount (oktas)                        -0.225539        -0.121452
# 3pm MSL pressure (hPa)                           1.000000        -0.237875
# MEANTEMPERATURE                                 -0.237875         1.000000
# Relative Humidity                               -0.031047        -0.311138
#
#                                    Relative Humidity
# TOTALDEMAND                                 0.064301
# Minimum temperature (°C)                   -0.055004
# Maximum temperature (°C)                   -0.456640
# Rainfall (mm)                               0.194560
# Evaporation (mm)                           -0.208511
# Sunshine (hours)                           -0.550315
# Speed of maximum wind gust (km/h)          -0.083759
# 9am Temperature (°C)                       -0.157132
# 9am relative humidity (%)                   0.402235
# 9am cloud amount (oktas)                    0.424203
# 9am MSL pressure (hPa)                     -0.143373
# 3pm Temperature (°C)                       -0.543138
# 3pm relative humidity (%)                   1.000000
# 3pm cloud amount (oktas)                    0.342130
# 3pm MSL pressure (hPa)                     -0.031047
# MEANTEMPERATURE                            -0.311138
# Relative Humidity                           1.000000

# %%
#visualization

# %%
sns.relplot(x='TOTALDEMAND', y='Relative Humidity', data=final_data)

# %%
sns.relplot(x='TOTALDEMAND', y='MEANTEMPERATURE', data=final_data)

# %%
sns.relplot(x='TOTALDEMAND', y='Rainfall (mm)', data=final_data)

# %%
sns.relplot(x='TOTALDEMAND', y='Speed of maximum wind gust (km/h)', data=final_data)

# %%
 #model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
final_data.columns
# Out:
# Index(['REGION', 'SETTLEMENTDATE', 'TOTALDEMAND', 'PRICECATEGORY',
#        'Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)',
#        'Evaporation (mm)', 'Sunshine (hours)',
#        'Direction of maximum wind gust ', 'Speed of maximum wind gust (km/h)',
#        'Time of maximum wind gust', '9am Temperature (°C)',
#        '9am relative humidity (%)', '9am cloud amount (oktas)',
#        '9am wind direction', '9am wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)', '3pm wind direction',
#        '3pm wind speed (km/h)', '3pm MSL pressure (hPa)', 'MEANTEMPERATURE',
#        'Relative Humidity'],
#       dtype='object')

# %%
final_data['Relative Humidity'] = final_data['3pm relative humidity (%)']/100

# %%
final_data.columns
# Out:
# Index(['REGION', 'SETTLEMENTDATE', 'TOTALDEMAND', 'PRICECATEGORY',
#        'Minimum temperature (°C)', 'Maximum temperature (°C)', 'Rainfall (mm)',
#        'Evaporation (mm)', 'Sunshine (hours)',
#        'Direction of maximum wind gust ', 'Speed of maximum wind gust (km/h)',
#        'Time of maximum wind gust', '9am Temperature (°C)',
#        '9am relative humidity (%)', '9am cloud amount (oktas)',
#        '9am wind direction', '9am wind speed (km/h)', '9am MSL pressure (hPa)',
#        '3pm Temperature (°C)', '3pm relative humidity (%)',
#        '3pm cloud amount (oktas)', '3pm wind direction',
#        '3pm wind speed (km/h)', '3pm MSL pressure (hPa)', 'MEANTEMPERATURE',
#        'Relative Humidity'],
#       dtype='object')

# %%
train = final_data.drop(['REGION','SETTLEMENTDATE', 'TOTALDEMAND', 'PRICECATEGORY', 'Minimum temperature (°C)', 'Maximum temperature (°C)', 'Evaporation (mm)', 'Sunshine (hours)',
       'Direction of maximum wind gust ', 'Rainfall (mm)', 'Speed of maximum wind gust (km/h)',
       'Time of maximum wind gust', '9am Temperature (°C)',
       '9am relative humidity (%)', '9am cloud amount (oktas)',
       '9am wind direction', '9am wind speed (km/h)', '9am MSL pressure (hPa)',
       '3pm Temperature (°C)', '3pm relative humidity (%)',
       '3pm cloud amount (oktas)', '3pm wind direction',
       '3pm wind speed (km/h)', '3pm MSL pressure (hPa)'], axis=1)

test = final_data['TOTALDEMAND']

# %%
train.columns
# Out:
# Index(['MEANTEMPERATURE', 'Relative Humidity'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(train, test, test_size=0.2, random_state=3)
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#X_pred = regr.predict(X_test)

# %%
y_pred = regr.predict(X_test)

# %%
#to output of the coefficient
regr.coef_
# Out:
# array([ -79.03045351, -218.65118035])

# %%
y_pred
# Out:
# array([6557.46582399, 6438.68312229, 6525.27412736, 6198.5622481 ,
#        6328.54099546, 6254.72656742, 6447.5871838 , 6387.31332751,
#        6043.03034668, 6417.66100612, 6607.83460261, 6028.98926685,
#        5849.40573559, 5504.62224668, 6097.00815419, 6379.33127502,
#        5682.862268  , 6558.65131964, 6635.4162542 , 6075.06402901,
#        6010.41714912, 6334.60002279, 5842.00319831, 6125.169321  ,
#        6513.34055219, 6041.34434295, 5760.18025257, 6262.55060563,
#        6262.1291047 , 5484.8646333 , 6348.37761598, 6572.61339232,
#        5761.70824201, 6074.56352094, 6529.14664289, 5512.26180538,
#        5607.36183623, 6263.97312271, 6138.10391232, 5378.17352106,
#        6338.13004454, 6306.67587742, 6299.03631871, 5689.73783199,
#        6415.89599525, 5910.1010928 , 6410.1794617 , 6560.25831622,
#        6031.75529387])

# %%
y_test
# Out:
# Date
# 10/07/2021    6825.14
# 24/07/2021    6492.94
# 23/07/2021    7329.83
# 1/07/2021     6752.13
# 16/06/2021    7031.11
# 24/06/2021    6787.77
# 23/06/2021    7077.89
# 3/08/2021     7197.61
# 14/04/2021    5731.88
# 25/08/2021    6736.80
# 22/07/2021    7536.62
# 19/04/2021    5937.22
# 14/01/2021    5257.95
# 3/04/2021     5723.27
# 31/08/2021    5779.56
# 21/05/2021    6736.74
# 1/04/2021     5807.02
# 27/08/2021    6769.89
# 5/06/2021     6484.85
# 11/08/2021    6687.69
# 30/04/2021    5887.34
# 12/08/2021    6537.70
# 8/01/2021     5365.19
# 17/04/2021    5450.82
# 6/07/2021     7281.69
# 3/03/2021     5526.41
# 24/03/2021    5549.13
# 10/08/2021    6234.67
# 24/05/2021    6354.64
# 16/02/2021    6816.18
# 13/07/2021    7174.57
# 26/08/2021    7126.76
# 18/03/2021    5691.57
# 7/05/2021     5957.64
# 24/08/2021    6717.65
# 17/02/2021    7230.71
# 4/02/2021     6015.71
# 14/06/2021    6366.51
# 27/04/2021    6487.76
# 18/02/2021    7508.61
# 5/05/2021     6389.08
# 28/04/2021    6461.27
# 19/08/2021    6344.80
# 19/03/2021    5467.08
# 8/08/2021     6477.76
# 5/04/2021     5078.44
# 30/06/2021    6648.79
# 31/05/2021    7042.12
# 16/03/2021    5580.93
# Name: TOTALDEMAND, dtype: float64

# %%
#to check the efficiency of model
regr.score(X_test, y_test)
# Out:
# 0.08352669590731698

# %%
train.corr()
# Out:
#                    MEANTEMPERATURE  Relative Humidity
# MEANTEMPERATURE           1.000000          -0.311138
# Relative Humidity        -0.311138           1.000000

# %%
#to check efficiency of model

from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test, y_pred))
# Out:
# 449.3501691829527

# %%
#to check the efficiency of model using r square

import statsmodels.api as sm

# %%
Y = final_data['TOTALDEMAND']
X_addC = sm.add_constant(train)
result = sm.OLS(Y, X_addC).fit()
print(result.rsquared, result.rsquared_adj)
# Out:
# 0.16652892483607884 0.15958333254304624

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TOTALDEMAND   R-squared:                       0.167
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     23.98
# Date:                Tue, 14 Dec 2021   Prob (F-statistic):           3.21e-10
# Time:                        06:00:16   Log-Likelihood:                -1951.4
# No. Observations:                 243   AIC:                             3909.
# Df Residuals:                     240   BIC:                             3919.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              7600.5936    316.994     23.977      0.000    6976.149    8225.039
# MEANTEMPERATURE     -81.1942     11.874     -6.838      0.000    -104.584     -57.805
# Relative Humidity  -393.7688    361.033     -1.091      0.277   -1104.967     317.429
# ==============================================================================
# Omnibus:                       44.972   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.767
# Skew:                           0.888   Prob(JB):                     3.57e-22
# Kurtosis:                       5.569   Cond. No.                         152.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
